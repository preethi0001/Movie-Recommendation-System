# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv('/content/rating.csv')
df2=pd.read_csv('/content/movie.csv')

# %%
df2.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
# what we need is that movie id and title
df2 = df2.loc[:,["movieId","title"]]
df2.head(10)
# Out:
#    movieId                               title
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)

# %%
df1.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
# what we need is that user id, movie id and rating
df1 = df1.loc[:,["userId","movieId","rating"]]
df1.head(10)
# Out:
#    userId  movieId  rating
# 0       1        2     3.5
# 1       1       29     3.5
# 2       1       32     3.5
# 3       1       47     3.5
# 4       1       50     3.5
# 5       1      112     3.5
# 6       1      151     4.0
# 7       1      223     4.0
# 8       1      253     4.0
# 9       1      260     4.0

# %%
# then merge movie and rating data
data = pd.merge(df2,df1)

# %%
# now lets look at our data 
data.head(10)
# Out:
#    movieId             title  userId  rating
# 0        1  Toy Story (1995)       3     4.0
# 1        1  Toy Story (1995)       6     5.0
# 2        1  Toy Story (1995)       8     4.0
# 3        1  Toy Story (1995)      10     4.0
# 4        1  Toy Story (1995)      11     4.5
# 5        1  Toy Story (1995)      12     4.0
# 6        1  Toy Story (1995)      13     4.0
# 7        1  Toy Story (1995)      14     4.5
# 8        1  Toy Story (1995)      16     3.0
# 9        1  Toy Story (1995)      19     5.0

# %%
data.shape
# Out:
# (1000000, 4)

# %%
data = data.iloc[:1000000,:]

# %%
# lets make a pivot table in order to make rows are users and columns are movies. And values are rating
pivot_table = data.pivot_table(index = ["userId"],columns = ["title"],values = "rating")
pivot_table.head(10)
# Out:
# title   'Til There Was You (1997)  'burbs, The (1989)  1-900 (06) (1994)  \
# userId
# 1                             NaN                 NaN                NaN
# 2                             NaN                 NaN                NaN
# 3                             NaN                 NaN                NaN
# 4                             NaN                 NaN                NaN
# 5                             NaN                 NaN                NaN
# 6                             NaN                 NaN                NaN
# 7                             NaN                 NaN                NaN
# 8                             NaN                 NaN                NaN
# 9                             NaN                 NaN                NaN
# 10                            NaN                 NaN                NaN
#
# title   101 Dalmatians (1996)  \
# userId
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10                        NaN
#
# title   101 Dalmatians (One Hundred and One Dalmatians) (1961)  \
# userId
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# 6                                                     NaN
# 7                                                     NaN
# 8                                                     NaN
# 9                                                     NaN
# 10                                                    NaN
#
# title   12 Angry Men (1957)  187 (One Eight Seven) (1997)  \
# userId
# 1                       NaN                           NaN
# 2                       NaN                           NaN
# 3                       NaN                           NaN
# 4                       NaN                           NaN
# 5                       NaN                           NaN
# 6                       NaN                           NaN
# 7                       NaN                           NaN
# 8                       NaN                           NaN
# 9                       NaN                           NaN
# 10                      NaN                           NaN
#
# title   1984 (Nineteen Eighty-Four) (1984)  2 Days in the Valley (1996)  \
# userId
# 1                                      NaN                          NaN
# 2                                      NaN                          NaN
# 3                                      5.0                          NaN
# 4                                      NaN                          NaN
# 5                                      NaN                          NaN
# 6                                      NaN                          NaN
# 7                                      NaN                          NaN
# 8                                      NaN                          NaN
# 9                                      NaN                          NaN
# 10                                     NaN                          NaN
#
# title   2 ou 3 choses que je sais d'elle (2 or 3 Things I Know About Her) (1967)  \
# userId
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# 6                                                     NaN
# 7                                                     NaN
# 8                                                     NaN
# 9                                                     NaN
# 10                                                    NaN
#
# title   ...  Young Doctors in Love (1982)  Young Frankenstein (1974)  \
# userId  ...
# 1       ...                           NaN                        4.0
# 2       ...                           NaN                        NaN
# 3       ...                           NaN                        5.0
# 4       ...                           NaN                        NaN
# 5       ...                           NaN                        NaN
# 6       ...                           NaN                        NaN
# 7       ...                           NaN                        NaN
# 8       ...                           NaN                        NaN
# 9       ...                           NaN                        NaN
# 10      ...                           NaN                        NaN
#
# title   Young Guns (1988)  Young Guns II (1990)  \
# userId
# 1                     NaN                   NaN
# 2                     NaN                   NaN
# 3                     NaN                   NaN
# 4                     NaN                   NaN
# 5                     NaN                   NaN
# 6                     NaN                   NaN
# 7                     NaN                   NaN
# 8                     NaN                   NaN
# 9                     NaN                   NaN
# 10                    NaN                   NaN
#
# title   Young Poisoner's Handbook, The (1995)  Young and Innocent (1937)  \
# userId
# 1                                         NaN                        NaN
# 2                                         NaN                        NaN
# 3                                         NaN                        NaN
# 4                                         NaN                        NaN
# 5                                         NaN                        NaN
# 6                                         NaN                        NaN
# 7                                         NaN                        NaN
# 8                                         NaN                        NaN
# 9                                         NaN                        NaN
# 10                                        NaN                        NaN
#
# title   Your Friends and Neighbors (1998)  Zero Effect (1998)  \
# userId
# 1                                     NaN                 NaN
# 2                                     NaN                 NaN
# 3                                     NaN                 NaN
# 4                                     NaN                 NaN
# 5                                     NaN                 NaN
# 6                                     NaN                 NaN
# 7                                     NaN                 NaN
# 8                                     NaN                 NaN
# 9                                     NaN                 NaN
# 10                                    NaN                 NaN
#
# title   Zero Kelvin (Kjærlighetens kjøtere) (1995)  Zeus and Roxanne (1997)
# userId
# 1                                              NaN                      NaN
# 2                                              NaN                      NaN
# 3                                              NaN                      NaN
# 4                                              NaN                      NaN
# 5                                              NaN                      NaN
# 6                                              NaN                      NaN
# 7                                              NaN                      NaN
# 8                                              NaN                      NaN
# 9                                              NaN                      NaN
# 10                                             NaN                      NaN
#
# [10 rows x 2247 columns]

# %%
movie_watched = pivot_table["Young Doctors in Love (1982)"]
similarity_with_other_movies = pivot_table.corrwith(movie_watched)  # find correlation between "Bad Boys (1995)" and other movies
similarity_with_other_movies = similarity_with_other_movies.sort_values(ascending=False)
similarity_with_other_movies.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:2683: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:2542: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# title
# Young Doctors in Love (1982)                 1.0
# Safe Passage (1994)                          1.0
# Tom and Huck (1995)                          1.0
# Seventh Heaven (Septième ciel, Le) (1997)    1.0
# Dead Presidents (1995)                       1.0
# dtype: float64
